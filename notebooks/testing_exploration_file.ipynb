# %%
import sys
sys.path.append("../src")

from exploration import run_exploration_pipeline

# %%
df = run_exploration_pipeline(
    input_path="../data/booking_reviews copy.csv",
    save_output=False,
    verbose=True
)
# Out:
# ...
# 1. LOADING RAW DATA
# ...
# Input path: ..\data\booking_reviews copy.csv
#
# ...
# 2. RAW DATA OVERVIEW
# ...
#
# Shape:
# (26675, 16)
#
# Columns:
# - index
# - review_title
# - reviewed_at
# - reviewed_by
# - images
# - crawled_at
# - url
# - hotel_name
# - hotel_url
# - avg_rating
# - nationality
# - rating
# - review_text
# - raw_review_text
# - tags
# - meta
#
# First 5 rows:
#    index                                       review_title       reviewed_at  \
# 0      0                                        Exceptional      11 July 2021
# 1      1  I highly recommend this b&b! We enjoyed it a lot!  24 November 2019
# 2      2                                        Exceptional    3 January 2020
# 3      3  My stay in the house was a experiencing bliss ...  8 September 2019
# 4      4  One bedroom apartment with wonderful view and ...      23 June 2019
#
#   reviewed_by                                             images  \
# 0      Kyrylo                                                NaN
# ...

# %%
df.head(5)
# Out:
#                                         review_title              hotel_name  \
# 0                                        Exceptional         Villa Pura Vida
# 1  I highly recommend this b&b! We enjoyed it a lot!         Villa Pura Vida
# 2                                        Exceptional  Hydro Palace Apartment
# 3  My stay in the house was a experiencing bliss ...         Villa Pura Vida
# 4  One bedroom apartment with wonderful view and ...  Hydro Palace Apartment
#
#    avg_rating     nationality  rating  \
# 0         9.7          Poland    10.0
# 1         9.7         Belgium     9.0
# 2         9.2  United Kingdom    10.0
# 3         9.7     Netherlands    10.0
# 4         9.2    South Africa     9.2
#
#                                          review_text  year      month  season  \
# 0  Everything was perfect! Quite, cozy place to r...  2021       July  Summer
# 1          Very friendly host and perfect breakfast!  2019   November  Autumn
# ...
